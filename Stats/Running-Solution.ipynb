# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from pylab import *
import scipy.stats as stats
import pylab



mpl.style.available
mpl.style.use('ggplot') 
# %matplotlib inline

# %% [markdown]
# ##Description
# 9 variables for all 16,924 10 mile participants in the 2012 Cherry Blossom Run.
#
# ##Format
#  The run10 (2012 data) summarizes 16,924 observations on 9 variables.
#
# place: Finishing position. Separate positions are provided for each gender.
#
# time: The total run time. For run10, this is equivalent to netTime. netTime The run time from the start line to the finish line.
#
# pace: The listed pace for each runner.
#
# age: Age.
#
# gender: Gender.
#
# location: Hometown city.
#
# state: Hometown state.
#
# divPlace: Division place, also broken up by gender. (Division is running devision by age.)
#
# divTot: Total number of people in the division (again, also split by gender).

# %% [markdown]
# Import as a dataframe run10.txt

# %%
df=pd.read_table('run10.txt')

# %% [markdown]
# Explore the first lines of the data

# %%
df.head()
# Out:
#    place    time    pace  age gender             location state  divPlace  \
# 0   4494   92.25   9.225   38      M  Chesapeake Beach MD    MD       690
# 1   6298  106.35  10.635   33      M        Washington DC    DC      1322
# 2   2502   89.33   8.933   55      F            McLean VA    VA        37
# 3   8176  113.50  11.350   24      F        Alexandria VA    VA       878
# 4   3413   86.52   8.652   54      M     San Francisco CA    CA       213
#
#    divTot
# 0    1093
# 1    1490
# 2     236
# 3     974
# 4     483

# %% [markdown]
# Get a summary of the data

# %%
df.head()
# Out:
#    place    time    pace  age gender             location state  divPlace  \
# 0   4494   92.25   9.225   38      M  Chesapeake Beach MD    MD       690
# 1   6298  106.35  10.635   33      M        Washington DC    DC      1322
# 2   2502   89.33   8.933   55      F            McLean VA    VA        37
# 3   8176  113.50  11.350   24      F        Alexandria VA    VA       878
# 4   3413   86.52   8.652   54      M     San Francisco CA    CA       213
#
#    divTot
# 0    1093
# 1    1490
# 2     236
# 3     974
# 4     483

# %% [markdown]
# Use pd.scatter_matrix(dataframe) on the dataframe to get an overview of the relationships between the variables.
# If you need to enlarge the plot add the argument figsize=(15,15) in pd.scatter_matrix.

# %%
pd.scatter_matrix(df,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x107991a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1039bb3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x103968990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x107f49cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x107fc2f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10802e0d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x108404390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x107f627d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1084ddc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108563a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1085cd1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10873fe50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x108795a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108824990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1088a8650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108b17410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108b9a410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108d001d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x108d83290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108d2d0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108e6ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108eecb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108f5e1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x108fd5f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10982ea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1098bd990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109941650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1099b2510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109b361d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109b9c0d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x109d11e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109bb4390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109e04b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109e88810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109eeced0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109f6fc90>]], dtype=object)

# %% [markdown]
# Study the relationship between the variables.

# %% [markdown]
# Use pd.scatter_matrix('Variable') to get an overview of the relationships between time,pace and age.

# %%
pd.scatter_matrix(df[['time','pace','age']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10b9aebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c4f4190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c49f410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x107aa4650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x107c40810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x107c5ac90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x107d31350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cbec610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109e1da10>]], dtype=object)

# %% [markdown]
# Study the graph and comment on the relations of the variables.

# %% [markdown]
# # Comparison of different groups.

# %% [markdown]
# Group the database by gender. In oder to group data use .groupby('Variable')

# %%
df1=df.groupby('gender')

# %% [markdown]
# Get a summary of the grouped data.

# %%
df1.describe()
# Out:
#                     place         time         pace          age     divPlace  \
# gender
# F      count  9732.000000  9732.000000  9732.000000  9732.000000  9732.000000
#        mean   4866.500000    99.015584     9.901558    33.877620   874.246301
#        std    2809.530744    14.681487     1.468149     9.274390   715.656644
#        min       1.000000    54.030000     5.403000    12.000000     1.000000
#        25%    2433.750000    89.080000     8.908000    27.000000   283.000000
#        50%    4866.500000    98.030000     9.803000    32.000000   692.000000
#        75%    7299.250000   107.900000    10.790000    39.000000  1315.000000
#        max    9732.000000   170.970000    17.097000    75.000000  2782.000000
# M      count  7192.000000  7192.000000  7192.000000  7191.000000  7191.000000
#        mean   3596.500000    88.434810     8.843481    37.745237   512.810736
#        std    2076.295901    15.521568     1.552157    10.866987   393.453447
#        min       1.000000    45.250000     4.525000     9.000000     1.000000
#        25%    1798.750000    77.560000     7.756000    29.000000   181.000000
#        50%    3596.500000    87.470000     8.747000    35.000000   418.000000
#        75%    5394.250000    97.780000     9.778000    45.000000   794.000000
#        max    7192.000000   150.980000    15.098000    89.000000  1490.000000
#
#                    divTot
# gender
# F      count  9732.000000
#        mean   1747.492602
#        std     879.194231
#        min       1.000000
#        25%     974.000000
#        50%    2228.000000
#        75%    2782.000000
#        max    2782.000000
# M      count  7191.000000
#        mean   1024.621471
#        std     449.353202
#        min       2.000000
#        25%     648.000000
#        50%    1093.000000
#        75%    1457.000000
#        max    1490.000000

# %% [markdown]
# Comment on the graph that is produced by following code and give an appropriate name in plt.legend()

# %%
for color, label in zip('bg', ['F','M']):
    subset = df[df.gender == label]
    plt.scatter(subset.time, subset.age, c=color, label=str(label))
plt.legend()

# %% [markdown]
# Produce a histogramm of time variable for the grouped data

# %%
df1.time.hist(normed=True,figsize=(7,7))
# Out:
# gender
# F         Axes(0.125,0.125;0.775x0.775)
# M         Axes(0.125,0.125;0.775x0.775)
# Name: time, dtype: object

# %% [markdown]
# Produce a histogramm for the grouped data and overimpose the fitted densities.

# %%
df1.time.hist(normed=True,figsize=(7,7))
df1.time.plot(kind='kde')
# Out:
# gender
# F         Axes(0.125,0.125;0.775x0.775)
# M         Axes(0.125,0.125;0.775x0.775)
# Name: time, dtype: object

# %% [markdown]
# Check graphically, if the running times of men, follow a normal distribution.

# %%
male_time=df['time'][df.gender=='M']
male_time.hist()

# %%
stats.probplot(male_time,plot=pylab)
# Out:
# ((array([-3.72833929, -3.49851474, -3.37211613, ...,  3.37211613,
#           3.49851474,  3.72833929]),
#   array([  45.25,   46.47,   47.55, ...,  147.5 ,  148.97,  150.98])),
#  (15.438580358551953, 88.434809510567305, 0.9942436607583206))
