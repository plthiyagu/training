# %% [markdown]
# # Import relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import pylab
import statsmodels.api as sm


import scipy.stats as stats
mpl.style.available
mpl.style.use('ggplot') 

# %matplotlib inline

# %% [markdown]
# ##Description
# These data represent incoming emails for the first three months of 2012 for an email account.
# ##Format
# A email (email_sent) data frame has 3921 (1252) observations on the following 21 variables.
#
# spam: Indicator for whether the email was spam.
#
# to_multiple: Indicator for whether the email was addressed to more than one recipient.
#
# from: Whether the message was listed as from anyone (this is usually set by default for regular outgoing email).
#
# cc: The number of people that were CCed.
#
# sent_email: Indicator for whether the sender had been sent an email in the last 30 days.
#
# time: Time at which email was sent.
#
# image: The number of images attached.
#
# attach: The number of attached files.
#
# dollar: The number of times a dollar sign or the word “dollar” appeared in the email.
#
# winner: Indicates whether “winner” appeared in the email.
#
# inherit: The number of times “inherit” (or an extension, such as “inheritance”) appeared in the email.
#
# viagra: The number of times “viagra” appeared in the email.
#
# password: The number of times “password” appeared in the email.
#
# num_char: The number of characters in the email, in thousands.
#
# line_breaks: The number of line breaks in the email (does not count text wrapping).
#
# format: Indicates whether the email was written using HTML (e.g. may have included bolding or active links).
#
# re_subj: Whether the subject started with “Re:”, “RE:”, “re:”, or “rE:”
#
# exclaim_subj: Whether there was an exclamation point in the subject.
#
# urgent_subj: Whether the word “urgent” was in the email subject.
#
# exclaim_mess: The number of exclamation points in the email message.
#
# number: Factor variable saying whether there was no number, a small number (under 1 million), or a big number.

# %% [markdown]
# Load email.txt on a data frame.

# %%
df=pd.read_table("email.txt")

# %% [markdown]
# Explore the data.

# %%
df.head()
# Out:
#    spam  to_multiple  from  cc  sent_email                 time  image  \
# 0     0            0     1   0           0  2011-12-31 22:16:41      0
# 1     0            0     1   0           0  2011-12-31 23:03:59      0
# 2     0            0     1   0           0  2012-01-01 08:00:32      0
# 3     0            0     1   0           0  2012-01-01 01:09:49      0
# 4     0            0     1   0           0  2012-01-01 02:00:01      0
#
#    attach  dollar winner  ...    viagra  password  num_char  line_breaks  \
# 0       0       0     no  ...         0         0    11.370          202
# 1       0       0     no  ...         0         0    10.504          202
# 2       0       4     no  ...         0         0     7.773          192
# 3       0       0     no  ...         0         0    13.256          255
# 4       0       0     no  ...         0         2     1.231           29
#
#    format  re_subj  exclaim_subj  urgent_subj  exclaim_mess  number
# 0       1        0             0            0             0     big
# 1       1        0             0            0             1   small
# 2       1        0             0            0             6   small
# 3       1        0             0            0            48   small
# 4       0        0             0            0             1    none
#
# [5 rows x 21 columns]

# %% [markdown]
# Explore the different types of variables  df.dtypes

# %%
df.dtypes
# Out:
# spam              int64
# to_multiple       int64
# from              int64
# cc                int64
# sent_email        int64
# time             object
# image             int64
# attach            int64
# dollar            int64
# winner           object
# inherit           int64
# viagra            int64
# password          int64
# num_char        float64
# line_breaks       int64
# format            int64
# re_subj           int64
# exclaim_subj      int64
# urgent_subj       int64
# exclaim_mess      int64
# number           object
# dtype: object

# %% [markdown]
# Change  cc, attach, dollar, winner, inherit and password to indicator factors.
#
# **Hint:** use df[var].map(lambda function)

# %%
df['cc']=df['cc'].map(lambda x: 1 if x>0 else 0)

# %%
df['attach']=df['attach'].map(lambda x: 1 if x>0 else 0)

# %%
df['dollar']=df['dollar'].map(lambda x: 1 if x>0 else 0)

# %%
df['inherit']=df['inherit'].map(lambda x: 1 if x>0 else 0)

# %%
df['winner']=df['winner'].map(lambda x: 1 if x=='yes' else 0)

# %%
df.head()
# Out:
#    spam  to_multiple  from  cc  sent_email                 time  image  \
# 0     0            0     1   0           0  2011-12-31 22:16:41      0
# 1     0            0     1   0           0  2011-12-31 23:03:59      0
# 2     0            0     1   0           0  2012-01-01 08:00:32      0
# 3     0            0     1   0           0  2012-01-01 01:09:49      0
# 4     0            0     1   0           0  2012-01-01 02:00:01      0
#
#    attach  dollar  winner   ...    viagra  password  num_char  line_breaks  \
# 0       0       0       0   ...         0         0    11.370          202
# 1       0       0       0   ...         0         0    10.504          202
# 2       0       1       0   ...         0         0     7.773          192
# 3       0       0       0   ...         0         0    13.256          255
# 4       0       0       0   ...         0         2     1.231           29
#
#    format  re_subj  exclaim_subj  urgent_subj  exclaim_mess  number
# 0       1        0             0            0             0     big
# 1       1        0             0            0             1   small
# 2       1        0             0            0             6   small
# 3       1        0             0            0            48   small
# 4       0        0             0            0             1    none
#
# [5 rows x 21 columns]

# %%
##Set X to be the explenatory variables to_multiple, cc, attach, dollar, winner, inherit, password, format,
##re_subj and exclaim_subj
X=df[['to_multiple', 'cc', 'attach', 'dollar', 'winner', 'inherit', 'password', 'format','re_subj','exclaim_subj']] 
X=sm.add_constant(X)
##Set y to be the respone variable spam
y=df.spam
##Set the logistic regression model
 
logit = sm.Logit(y, X)
 
## fit the model
ess = logit.fit()
##See the summary statistics
ess.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.248026
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3910
# Method:                           MLE   Df Model:                           10
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.2019
# Time:                        13:19:25   Log-Likelihood:                -972.51
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                 2.090e-99
# ================================================================================
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# const           -0.8378      0.096     -8.718      0.000        -1.026    -0.649
# to_multiple     -2.8827      0.312     -9.237      0.000        -3.494    -2.271
# cc              -0.4838      0.306     -1.583      0.113        -1.083     0.115
# attach           0.9783      0.217      4.510      0.000         0.553     1.403
# dollar          -0.0582      0.159     -0.366      0.714        -0.370     0.253
# winner           1.7034      0.327      5.208      0.000         1.062     2.344
# inherit          0.2064      0.320      0.646      0.519        -0.420     0.833
# password        -0.7347      0.295     -2.493      0.013        -1.312    -0.157
# format          -1.5853      0.124    -12.791      0.000        -1.828    -1.342
# re_subj         -2.9094      0.371     -7.846      0.000        -3.636    -2.183
# exclaim_subj     0.1369      0.227      0.603      0.547        -0.308     0.582
# ================================================================================
# """

# %% [markdown]
# Apply the Backwards selection strategy to come up with the "best" model.

# %% [markdown]
# Exclude dollar and refit the model.

# %%
##Set X to be the explenatory variables to_multiple, cc, attach, dollar, winner, inherit, password, format,
##re_subj and exclaim_subj
X=df[['to_multiple', 'cc', 'attach',  'winner', 'inherit', 'password', 'format','re_subj','exclaim_subj']] 
X=sm.add_constant(X)
##Set y to be the respone variable spam
y=df.spam
##Set the logistic regression model
 
logit = sm.Logit(y, X)
 
## fit the model
ess = logit.fit()
##See the summary statistics
ess.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.248043
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3911
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.2019
# Time:                        13:20:10   Log-Likelihood:                -972.58
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                2.932e-100
# ================================================================================
#                    coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# const           -0.8476      0.092     -9.173      0.000        -1.029    -0.666
# to_multiple     -2.8773      0.312     -9.227      0.000        -3.489    -2.266
# cc              -0.4807      0.305     -1.574      0.116        -1.079     0.118
# attach           0.9852      0.216      4.560      0.000         0.562     1.409
# winner           1.6944      0.326      5.202      0.000         1.056     2.333
# inherit          0.1696      0.303      0.559      0.576        -0.425     0.764
# password        -0.7322      0.294     -2.488      0.013        -1.309    -0.155
# format          -1.5867      0.124    -12.807      0.000        -1.830    -1.344
# re_subj         -2.9061      0.371     -7.839      0.000        -3.633    -2.179
# exclaim_subj     0.1149      0.219      0.525      0.600        -0.314     0.544
# ================================================================================
# """

# %% [markdown]
# Exclude exclaim_subj and refit the model.

# %%
##Set X to be the explenatory variables to_multiple, cc, attach, dollar, winner, inherit, password, format,
##re_subj and exclaim_subj
X=df[['to_multiple', 'cc', 'attach','inherit', 'winner', 'password', 'format','re_subj']] 
X=sm.add_constant(X)
##Set y to be the respone variable spam
y=df.spam
##Set the logistic regression model
 
logit = sm.Logit(y, X)
 
## fit the model
ess = logit.fit()
##See the summary statistics
ess.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.248078
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3912
# Method:                           MLE   Df Model:                            8
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.2018
# Time:                        13:21:07   Log-Likelihood:                -972.71
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                4.132e-101
# ===============================================================================
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const          -0.8422      0.092     -9.175      0.000        -1.022    -0.662
# to_multiple    -2.8698      0.311     -9.214      0.000        -3.480    -2.259
# cc             -0.4754      0.305     -1.558      0.119        -1.073     0.123
# attach          0.9807      0.216      4.547      0.000         0.558     1.403
# inherit         0.1581      0.303      0.522      0.601        -0.435     0.751
# winner          1.7094      0.324      5.268      0.000         1.073     2.345
# password       -0.7315      0.294     -2.484      0.013        -1.309    -0.154
# format         -1.5790      0.123    -12.848      0.000        -1.820    -1.338
# re_subj        -2.9128      0.370     -7.862      0.000        -3.639    -2.187
# ===============================================================================
# """

# %% [markdown]
# Exclude inherit and refit the model.

# %%
##Set X to be the explenatory variables to_multiple, cc, attach, dollar, winner, inherit, password, format,
##re_subj and exclaim_subj
X=df[['to_multiple', 'cc', 'attach', 'winner', 'password', 'format','re_subj']] 
X=sm.add_constant(X)
##Set y to be the respone variable spam
y=df.spam
##Set the logistic regression model
 
logit = sm.Logit(y, X)
 
## fit the model
ess = logit.fit()
##See the summary statistics
ess.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.248111
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3913
# Method:                           MLE   Df Model:                            7
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.2017
# Time:                        13:21:47   Log-Likelihood:                -972.84
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                5.412e-102
# ===============================================================================
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const          -0.8407      0.092     -9.164      0.000        -1.021    -0.661
# to_multiple    -2.8692      0.311     -9.215      0.000        -3.479    -2.259
# cc             -0.4738      0.305     -1.554      0.120        -1.071     0.124
# attach          0.9757      0.215      4.532      0.000         0.554     1.398
# winner          1.7224      0.324      5.316      0.000         1.087     2.357
# password       -0.7347      0.295     -2.494      0.013        -1.312    -0.157
# format         -1.5691      0.121    -12.943      0.000        -1.807    -1.332
# re_subj        -2.9197      0.370     -7.886      0.000        -3.645    -2.194
# ===============================================================================
# """

# %% [markdown]
# Exclude cc and refit the model.

# %%
##Set X to be the explenatory variables to_multiple, cc, attach, dollar, winner, inherit, password, format,
##re_subj and exclaim_subj
X=df[['to_multiple', 'attach', 'winner', 'password', 'format','re_subj']] 
X=sm.add_constant(X)
##Set y to be the respone variable spam
y=df.spam
##Set the logistic regression model
 
logit = sm.Logit(y, X)
 
## fit the model
ess = logit.fit()
##See the summary statistics
ess.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.248439
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   spam   No. Observations:                 3921
# Model:                          Logit   Df Residuals:                     3914
# Method:                           MLE   Df Model:                            6
# Date:                Tue, 03 Mar 2015   Pseudo R-squ.:                  0.2006
# Time:                        13:22:25   Log-Likelihood:                -974.13
# converged:                       True   LL-Null:                       -1218.6
#                                         LLR p-value:                2.047e-102
# ===============================================================================
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const          -0.8610      0.091     -9.467      0.000        -1.039    -0.683
# to_multiple    -2.8364      0.309     -9.174      0.000        -3.442    -2.230
# attach          0.8642      0.204      4.233      0.000         0.464     1.264
# winner          1.7372      0.324      5.368      0.000         1.103     2.371
# password       -0.7295      0.294     -2.484      0.013        -1.305    -0.154
# format         -1.5521      0.121    -12.861      0.000        -1.789    -1.316
# re_subj        -3.0490      0.363     -8.399      0.000        -3.760    -2.337
# ===============================================================================
# """

# %% [markdown]
# We keep this model since all the p-values are less than 0.05

# %%
ess.params
# Out:
# const         -0.861022
# to_multiple   -2.836407
# attach         0.864191
# winner         1.737171
# password      -0.729482
# format        -1.552071
# re_subj       -3.048989
# dtype: float64

# %% [markdown]
# Write the final logistic regression model.

# %%
hat_p=1/(1+np.exp(-0.861022-2.836407*df.to_multiple+0.864191*df.attach+1.737171*df.winner-0.729482*df.password-1.552071*df.format-3.048989*df.re_subj))

# %% [markdown]
# How will the probability change if the is the world password in the email?

# %% [markdown]
# All else kept constant, the probability of an email being spam, given that there is the word password,  will increase.
